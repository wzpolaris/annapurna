# %% [markdown]
# ### RBSA Notebook - Private Equity Analyzer - AI Prototype

# %% [markdown]
# #### Overview
#
# This notebook is a prototype that how AI can facilitate and strengthen analytics of PE investments.
#
# Often a user just wants "the answer," and in many cases this is reasonable.
#
# However, in analyzing Private Equity, limited partners and potential investors do not get full details, and the analytics for PE investments, therefore, are not "cookie cutter."
#
# Engaging with a user to develop insights and make informed decisions is essential.
#
# In this prototype, AI is used to incorporate incomplete information and judgements, and to identify questions that deserve further investigation.

# %%
import os, sys, yaml, pandas as pd, numpy as np
from IPython.display import display

# Add parent directory to path so we can import rbsa module
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from rbsa.main_pipeline import load_config, load_raw_data, prepare_data, run_all_methods, finalize_results
from rbsa.rbsa_initialize import summarizer, checkpoint_runner
from rbsa.reporting import format_weights, format_final_results

cfg = load_config(os.path.join(project_root, "config.yaml"))
raw_data = load_raw_data(cfg, project_root)
# Out:
# ✓ Batch mode
# Loading portfolio from data/portfolio.csv
# Portfolio: 2 holdings
#   ticker   wt
# 0  EVSYX  0.5
# 1  VWEHX  0.5
# Downloading 14 selection tickers + 5 substitution-only tickers

# %%
# checkpoint_runner = None
# if cfg.get('interactive', {}).get('enabled', False):
#     from rbsa import CheckpointRunner
#     checkpoint_runner = CheckpointRunner(cfg, summarizer)
#     print('✓ Interactive mode enabled')
# else:
#     print('✓ Batch mode')
#checkpoint_runner

# %% [markdown]
# #### Preliminary Diagnostics — Checking for Smoothed Returns
#
# Estimated or appraisal-based valuations typically smooths reported returns.
#
# This can lead to an underestimation of risk and reduces accuracy of returns-based analyses.

# %%
data = prepare_data(cfg, project_root, raw_data, checkpoint_runner=checkpoint_runner)
# Out:
# ================================================================================
# AR(1) AUTOCORRELATION TEST - Preliminary Diagnostics
# ================================================================================
# Sample size: 237 observations
# AR(1) coefficient (ρ): 0.038522
# AR(1) p-value: 0.553799
# Ljung-Box p-value (lag 1): 0.550844
# Significance level: 0.05
#
# ○ Positive autocorrelation (ρ=0.0385) but NOT significant (p=0.5538)
#   → No de-smoothing needed
# ================================================================================
# Selection universe: 14 assets
# Full universe (including substitutions): 19 assets
# After cleaning: 221 observations, 12 selection assets, 17 total assets

# %% [markdown]
# #### Approach A — Constrained RBSA

# %%
from rbsa.models.approach_a import approach_A_pipeline
resA = approach_A_pipeline(data["X"], data["y"], cfg)
resA["summary"] = summarizer.summarize(f"Selected: {', '.join(resA['selected'])}\nRMSE={resA['diagnostics']['rmse']:.6f}")
display(format_weights(resA["weights"]))
print(resA["summary"])
# Out:
#        weight
# HYG  0.292147
# IWF  0.286630
# IWD  0.235783
# BIL  0.135705
# TIP  0.049735
# Here’s a concise style snapshot and what to do with it.
#
# Fit quality
# - RMSE 0.00448 (~45 bps/month) suggests a strong fit; factor mix explains most of the return variance.
#
# Implied style exposures
# - Equity: Blend of US large-cap growth (IWF) and value (IWD). Net tilt depends on their relative weights; together they behave close to a core large-cap sleeve with style rotation risk.
# - Credit: High yield (HYG) adds spread and equity-like cyclicality; biggest left-tail risk in stress episodes.
# - Rates/Inflation: TIP adds real-rate duration and positive inflation beta; BIL adds cash/defensive ballast and liquidity.
# - Net takeaway: Pro-cyclical (IWF/IWD/HYG) tempered by an inflation hedge (TIP) and cash buffer (BIL).
#
# Key risk drivers and regime sensitivity
# - Risk-on/soft landing: IWF/IWD/HYG drive upside; BIL drags; TIP mixed (depends on real yields).
# - Risk-off/recession: HYG and equities draw down together; BIL cushions; TIP helps if real yields fall (flight-to-quality), hurts if real yields rise.
# - Stagflation: TIP helps; HYG/equities pressured.
# - Spread-widening shock: HYG is the main vulnerability; consider pre-hedging with duration.
#
# Overlaps and efficiency
# - IWF + IWD largely replicate a broad US large-cap core; keeping both is fine for dialable style, but redundant if you don’t want active style tilts.
# - Portfolio is US-centric; no explicit international, small/mid, or duration to nominal Treasuries.
#
# Actionable tweaks (pick based on objectives)
# - Reduce drawdowns: Trim HYG; add nominal Treasury duration (IEF/TLT) to hedge equity/credit; keep BIL as dry powder. Alternatively swap HYG → IG credit (LQD) or short-duration HY (SHYG).
# - Increase return/“risk-on”: Shift BIL/TIP into IWF/IWD or HYG; decide a clear style tilt (favor IWF if expecting continued multiple resilience; IWD if expecting value/cycle rebound).
# - Inflation resilience: Raise TIP weight; consider shorter-duration TIPS if concerned about rising real yields. Complement with real assets if allowed.
# - Simplify equity sleeve: Replace IWF+IWD with a core (IWB) if you don’t want style rotation risk.
# - Improve cash carry: If comfortable with small credit/rate risk, move some BIL to ultra-short IG (e.g., JPST/NEAR) for higher carry.
#
# Monitoring checklist
# - Credit spreads and earnings revisions (for HYG and equities).
# - Real yields and breakevens (for TIP).
# - Growth vs value relative strength (for IWF/IWD balance).
# - Correlation spikes: In stress, HYG and equities co-move; ensure you have a true diversifier (Treasury duration or more BIL).
#
# If you share the inferred weights or target constraints, I can quantify equity beta, spread beta, real-rate sensitivity, and each sleeve’s contribution to total variance.

# %% [markdown]
# #### Approach B — Elastic Net
#
# <!-- (auto α and λ) → constrained refit -->

# %%
import importlib
import rbsa.models.approach_b
importlib.reload(rbsa.models.approach_b)
from rbsa.models.approach_b import approach_B_pipeline

print("Starting Approach B with verbose=True")
resB = approach_B_pipeline(data["X"], data["y"], cfg, verbose=True)
print("Approach B completed")
resB["summary"] = summarizer.summarize(f"Selected: {', '.join(resB['selected'])}\nRMSE={resB['diagnostics'].get('rmse', float('nan'))}")
display(format_weights(resB["weights"]))
print(resB["summary"])
# Out:
# Starting Approach B with verbose=True
#
# ElasticNet Selection (testing 4 l1_ratio values):
# ================================================================================
#
#   l1_ratio=0.25: Selected 7 assets: DBC, HYG, IEF, IWD, IWF, LQD, TIP
#               Top coefficients: IWF=0.013, IWD=0.010, HYG=0.007
#               RBSA refit: R²=0.9743, Adj-R²=0.9735, MSE=0.000025, MAE=0.003487
#               Weights: HYG=0.302, IWF=0.275, IWD=0.240, TIP=0.165, LQD=0.014, DBC=0.004, IEF=0.000
#
#   l1_ratio=0.50: Selected 7 assets: DBC, HYG, IEF, IWD, IWF, LQD, TIP
#               Top coefficients: IWF=0.013, IWD=0.010, HYG=0.007
#               RBSA refit: R²=0.9743, Adj-R²=0.9735, MSE=0.000025, MAE=0.003487
#               Weights: HYG=0.302, IWF=0.275, IWD=0.240, TIP=0.165, LQD=0.014, DBC=0.004, IEF=0.000
#
#   l1_ratio=0.75: Selected 7 assets: DBC, HYG, IEF, IWD, IWF, LQD, TIP
#               Top coefficients: IWF=0.013, IWD=0.010, HYG=0.007
#               RBSA refit: R²=0.9743, Adj-R²=0.9735, MSE=0.000025, MAE=0.003487
#               Weights: HYG=0.302, IWF=0.275, IWD=0.240, TIP=0.165, LQD=0.014, DBC=0.004, IEF=0.000
#
#   l1_ratio=1.00: Selected 7 assets: DBC, HYG, IEF, IWD, IWF, LQD, TIP
#               Top coefficients: IWF=0.013, IWD=0.010, HYG=0.007
#               RBSA refit: R²=0.9743, Adj-R²=0.9735, MSE=0.000025, MAE=0.003487
#               Weights: HYG=0.302, IWF=0.275, IWD=0.240, TIP=0.165, LQD=0.014, DBC=0.004, IEF=0.000
#
# Selection frequency (need >=2/4 to be selected):
#   DBC: 4/4
#   HYG: 4/4
#   IEF: 4/4
#   IWD: 4/4
#   IWF: 4/4
#   LQD: 4/4
#   TIP: 4/4
#
# Final selected assets: DBC, HYG, IEF, IWD, IWF, LQD, TIP
#
# ================================================================================
# Refitting with NNLS (sum_to_one=True)...
# Final weights:
#   DBC: 0.0043
#   HYG: 0.3023
#   IEF: 0.0000
#   IWD: 0.2399
#   IWF: 0.2748
#   LQD: 0.0139
#   TIP: 0.1647
#
# Diagnostics: RMSE=0.004996
# Approach B completed
#            weight
# HYG  3.023085e-01
# IWF  2.747930e-01
# IWD  2.399229e-01
# TIP  1.647320e-01
# LQD  1.389408e-02
# DBC  4.349481e-03
# IEF  6.824092e-19
# Here’s what your RBSA selection implies and how to act on it.
#
# Big picture
# - The mix maps to four core betas: equity style (IWF/IWD), credit (HYG/LQD), duration (IEF plus the duration inside LQD/TIP), and inflation (TIP/DBC).
# - RMSE ≈ 0.50% monthly (~1.7% annualized TE) suggests the portfolio is well explained by these factors; residual/alpha is small.
#
# Key exposures and overlaps
# - Duration: IEF, TIP, and the Treasury component inside LQD all add rate sensitivity. You may be double-counting rate risk.
# - Credit: LQD (IG) and HYG (HY) load on spread risk; they are correlated and both weaken crisis ballast.
# - Equity beta/style: IWF vs IWD sets growth vs value tilt; net tilt determines sensitivity to rates and cyclicality.
# - Inflation: TIP and DBC both load on inflation; TIP responds to breakevens, DBC to spot commodities (energy-heavy).
#
# Actionable adjustments
# - Reduce rate sensitivity: cut IEF and/or shift LQD to shorter IG (e.g., IGSB) or to equity/DBC; keep TIP only if you want inflation hedge.
# - Strengthen inflation hedge: increase TIP and DBC; reduce nominal duration (IEF/LQD); tilt equity toward value (IWD).
# - De-risk credit: trim HYG first, then LQD; replace with IEF/TIP or cash to keep duration without spread risk.
# - Improve drawdown protection: increase pure Treasuries (IEF or even TLT) and decrease HYG/LQD; avoid relying on LQD as a safe haven.
# - Clarify style bet: if overweight growth (IWF > IWD), you’re more rate-sensitive; for a cyclical/inflation tilt, raise IWD and DBC, cut IWF and nominal duration.
# - Reduce redundancy: decide whether you want duration via IEF/TIP or via LQD; holding heavy weights in all three is inefficient.
#
# What to monitor
# - Effective duration (IEF + TIP + the duration in LQD): main driver of moves when yields shift.
# - Credit spread beta (HYG + LQD): primary risk-off vulnerability.
# - Net style tilt (IWF minus IWD): sensitivity to rate moves and sector dispersion.
# - Inflation beta (TIP + DBC): protection against breakeven/commodity shocks.
#
# Scenario sensitivities (directional)
# - Rates +100 bps, breakevens flat: IEF/LQD/TIP down; growth (IWF) lags value (IWD); DBC mixed.
# - Inflation surprise up, real yields flat: TIP/DBC up; nominal bonds lag; value tends to outperform.
# - Credit spread widening/risk-off: HYG/LQD down; IEF up; DBC usually down unless energy spikes; equities weaker (growth often more).
# - Soft-landing risk-on: HYG/LQD and equities up; IEF/TIP likely slip.
#
# If you share factor weights and sample window, I can quantify:
# - Equity beta and growth–value tilt
# - Effective duration (years) and inflation beta
# - Credit spread sensitivity and contributions to variance
# - Rolling stability of exposures and stress P&L estimates

# %% [markdown]
# #### Approach C — Bayesian RBSA
#
# <!-- with Dirichlet-Spike Prior -->

# %%
import importlib
import rbsa.models.approach_c
importlib.reload(rbsa.models.approach_c)
from rbsa.models.approach_c import approach_C_pipeline

print("Starting Approach C - Bayesian RBSA")
resC = approach_C_pipeline(data["X"], data["y"], cfg, verbose=True)
print("\nApproach C completed")
resC["summary"] = summarizer.summarize(f"Selected: {', '.join(resC['selected'])}\nR²={resC['diagnostics'].get('r2', float('nan')):.4f}")
display(format_weights(resC["weights"]))
print(resC["summary"])

# Show posterior inclusion probabilities
print("\nPosterior Inclusion Probabilities (top 10):")
display(resC["pip"].sort_values(ascending=False).head(10))
# Out:
# Starting Approach C - Bayesian RBSA
#
# Bayesian RBSA with Dirichlet-Spike Prior
# ================================================================================
# Running MCMC: 5000 samples, 1000 burn-in
#   Iteration 1000/5000, active assets: 7, sigma²=0.000118
#   Iteration 2000/5000, active assets: 6, sigma²=0.000136
#   Iteration 3000/5000, active assets: 6, sigma²=0.000127
#   Iteration 4000/5000, active assets: 7, sigma²=0.000106
#   Iteration 5000/5000, active assets: 5, sigma²=0.000117
#
# Posterior Inclusion Probabilities (PIP):
# asset     PIP  mean_weight  std_weight
#   HYG 1.00000     0.307504    0.039867
#   IWD 1.00000     0.232566    0.031975
#   IWF 1.00000     0.287731    0.028413
#   BIL 0.93775     0.152055    0.053808
#   TIP 0.38250     0.017461    0.050101
#   AGG 0.31400     0.000336    0.001608
#   LQD 0.30225     0.000846    0.004090
#   IWM 0.29450     0.000255    0.001361
#   DBC 0.29375     0.000191    0.001054
#   EEM 0.29125     0.000342    0.001935
#   EFA 0.28725     0.000459    0.002376
#   IEF 0.28100     0.000255    0.001208
#
# Selected assets (PIP >= 0.5): BIL, HYG, IWD, IWF
#
# ================================================================================
# Final NNLS weights (PIP >= 0.5):
#   HYG: 0.3070 (PIP=1.000)
#   IWF: 0.2907 (PIP=1.000)
#   IWD: 0.2303 (PIP=1.000)
#   BIL: 0.1720 (PIP=0.938)
#
# Diagnostics: R²=0.9788, RMSE=0.004539
#
# Approach C completed
#        weight
# HYG  0.306996
# IWF  0.290705
# IWD  0.230337
# BIL  0.171963
# Here’s what your RBSA setup implies and how to act on it:
#
# Fit and residual risk
# - R²=0.9788: very high fit; only 2.12% of variance unexplained. Residual (idiosyncratic) vol ≈ sqrt(1−R²) ≈ 14.6% of total volatility.
# - Interpretation: your portfolio can be closely replicated by a mix of cash (BIL), high-yield credit (HYG), and large-cap value/growth (IWD/IWF).
#
# Factor exposures and implications
# - Equity beta: Driven by IWD + IWF. If their weights are similar, you’re large-cap core; imbalance implies a clear value or growth tilt.
# - Credit beta: HYG adds pro‑cyclical spread risk that is positively correlated with equities; boosts carry but increases drawdown risk in stress.
# - Cash/defensiveness: BIL dampens volatility and drawdowns but creates cash drag; minimal duration exposure overall (no Treasury ballast).
# - Collinearity: IWD and IWF are highly correlated; weights can be unstable over time even if the net equity beta is stable.
#
# Risk and scenario takeaways
# - Risk stack: Equity and credit dominate; limited interest-rate hedge.
# - Equity selloff + spread widening: HYG and IWD/IWF likely fall together; BIL cushions. Each 10% in HYG can behave like several percent of equity risk in stress.
# - Value vs growth rotations: Relative P&L hinges on IWD vs IWF weights.
# - Rates rally (yields down): Little benefit without Treasury duration (BIL ~0 duration; HYG duration is modest and can be offset by spread moves).
#
# Actionable adjustments (choose by objective)
# - Reduce drawdowns/left-tail risk:
#   - Trim HYG; add intermediate/long Treasuries (e.g., IEF/TLT) as a separate factor to introduce true duration ballast.
#   - Keep some BIL for liquidity but consider replacing part with Treasuries to earn convexity in risk-off regimes.
# - Neutral equity style:
#   - Set IWD ≈ IWF to target large-cap core; tilt deliberately if you want factor bets (e.g., value > growth).
# - Improve carry with controlled beta:
#   - Prefer IG credit (LQD) or short-duration IG (IGSB) over more HYG if you want spread premium with less equity-like drawdown.
# - Stabilize exposures:
#   - Replace IWD/IWF pair with SPY (broad beta) plus a value-minus-growth sleeve (e.g., IWD–IWF) to reduce multicollinearity.
# - Risk budgeting:
#   - Cap HYG to a fixed share of total risk (not just weight). Monitor rolling 36m factor contributions and ensure credit ≤ X% of portfolio volatility.
#
# Diagnostics to run next
# - Share the regression coefficients/weights (and constraints used) to quantify:
#   - Net equity beta (IWD+IWF plus any implicit via HYG)
#   - Credit spread exposure (HYG)
#   - Cash/defensive share (BIL)
#   - Residual tracking error in annualized terms
# - Test stability: rolling-window RBSA and out-of-sample fit; watch for weight flipping between IWD and IWF.
# - Add a duration factor (Treasuries) to avoid misattributing rate moves to equities/credit.
#
# If you provide the regression weights and sample period, I’ll quantify risk contributions, implied betas, and suggest precise reweights aligned with your objective (drawdown target, volatility budget, or factor neutrality).
#
# Posterior Inclusion Probabilities (top 10):
# HYG    1.00000
# IWD    1.00000
# IWF    1.00000
# BIL    0.93775
# TIP    0.38250
# AGG    0.31400
# LQD    0.30225
# IWM    0.29450
# DBC    0.29375
# EEM    0.29125
# dtype: float64

# %% [markdown]
# #### Approach D — Cluster-then-Span

# %%
from rbsa.models.approach_d import approach_D_pipeline
resD = approach_D_pipeline(data["X"], data["y"], cfg)
resD["summary"] = summarizer.summarize(f"Selected: {', '.join(resD['selected'])}\nRMSE={resD['diagnostics']['rmse']:.6f}")
display(format_weights(resD["weights"]))
print(resD["summary"])
# Out:
#        weight
# HYG  0.292147
# IWF  0.286630
# IWD  0.235783
# BIL  0.135705
# TIP  0.049735
# Concise takeaways from the selected basis set (HYG, IWF, IWD, BIL, TIP):
#
# What the exposures imply
# - Core US large-cap equity with a style barbell: IWF (growth) + IWD (value) suggests a mostly style-neutral large-cap core; relative weights indicate the growth/value tilt.
# - Credit beta via HYG: meaningful exposure to credit spreads and equity-like drawdowns in risk-off regimes.
# - Rates/inflation via TIP: real-rate duration plus inflation surprise protection; TIP helps if inflation rises relative to expectations but falls when real yields rise.
# - Cash via BIL: liquidity and drawdown dampener; indicates some market-timing or dry powder.
#
# Risk/return drivers to watch
# - Equity vs style rotation: Performance sensitive to growth–value cycles; check the net tilt (IWF minus IWD).
# - Spread risk: HYG will likely sell off alongside equities in stress; concentrates cyclical risk.
# - Real-rate shock: TIP has material real-duration; +100 bps real yield hurts TIP, even if inflation is stable.
# - Liquidity cushion: BIL reduces volatility and max drawdown but lowers carry.
#
# Actionable adjustments by objective
# - Reduce drawdowns: Trim HYG; shift some IWF/IWD to min-vol/quality or add nominal duration (IEF/TLT) instead of TIP for better equity-hedge convexity; maintain or increase BIL.
# - Increase carry/income: Increase HYG modestly and reduce BIL, but cap HYG to a risk limit (e.g., ≤15–20% of risk budget) to control spread shocks.
# - Lean into inflation risk: Raise TIP, reduce HYG and growth-heavy equity; pair with some commodities (if allowed) for purer inflation beta.
# - Disinflation/rates rally view: Lower TIP, add nominal duration (IEF/TLT); keep equity style more growth-tilted if betting on lower real rates.
# - Clarify style bet: If unintended, balance IWF and IWD weights to neutralize growth/value; if intended, size the tilt and monitor its contribution to tracking error.
#
# Monitoring and controls
# - Track equity beta (to SPY), net growth–value exposure (IWF minus IWD), credit-spread beta (HYG), and real-rate beta (TIP).
# - Stress test: 2018Q4/2020Q1/2022 bear—expect HYG and equities to co-move; assess how much BIL offsets.
# - Watch breakeven inflation and real yields; TIP’s PnL is driven more by real yields than CPI prints over short horizons.
#
# Fit quality
# - RMSE ≈ 0.45% per period (likely monthly) implies ~1.5% annualized tracking error—good explanatory power. Residuals likely come from idiosyncratic positions or factors not in the set (small-cap, quality, momentum, term structure beyond TIP/BIL).
#
# If you share the estimated weights, I can quantify factor betas, scenario PnL, and risk contributions to refine the recommendations.

# %% [markdown]
# #### Final Consolidation — Top Candidates

# %%
from rbsa.consolidate import create_diagnostic_questions

# Add approach labels to candidates
all_cands = [
    {"approach": "A", **resA},
    {"approach": "B", **resB},
    {"approach": "C", **resC},
    {"approach": "D", **resD},
]

# Rank by performance
final_ranked = finalize_results(all_cands, cfg)

# Display formatted results
print(format_final_results(final_ranked))

mode = cfg.get("analysis", {}).get("mode", "in_sample")
print(f"\nAnalysis mode: {mode}")

# Diagnostic questions
print("\nDiagnostic Questions:")
display(create_diagnostic_questions(final_ranked))
# Out:
# Candidate 1 (Method A):
#   Statistics: n_assets=5, R²=0.979321, Adj-R²=0.978840, RMSE=0.004482, MAE=0.003017, AIC=-1753.05, AICc=-1752.77, BIC=-1736.05
#   Assets:     HYG(0.292), IWF(0.287), IWD(0.236), BIL(0.136), TIP(0.050)
#
# Candidate 2 (Method D):
#   Statistics: n_assets=5, R²=0.979321, Adj-R²=0.978840, RMSE=0.004482, MAE=0.003017, AIC=-1753.05, AICc=-1752.77, BIC=-1736.05
#   Assets:     HYG(0.292), IWF(0.287), IWD(0.236), BIL(0.136), TIP(0.050)
#
# Candidate 3 (Method C):
#   Statistics: n_assets=4, R²=0.978787, Adj-R²=0.978394, RMSE=0.004539, MAE=0.003032, AIC=-1749.41, AICc=-1749.23, BIC=-1735.82
#   Assets:     HYG(0.307), IWF(0.291), IWD(0.230), BIL(0.172)
#
# Candidate 4 (Method B):
#   Statistics: n_assets=7, R²=0.974304, Adj-R²=0.973459, RMSE=0.004996, MAE=0.003487, AIC=-1701.04, AICc=-1700.51, BIC=-1677.25
#   Assets:     HYG(0.302), IWF(0.275), IWD(0.240), TIP(0.165), LQD(0.014), DBC(0.004), IEF(0.000)
#
#
# Analysis mode: in_sample
#
# Diagnostic Questions:
#                                                      q1  \
# rank
# 1     If the fund's mandate restricts leverage/cash,...
# 2     If the fund's mandate restricts leverage/cash,...
# 3     If the fund's mandate restricts leverage/cash,...
# 4     If the fund's mandate restricts leverage/cash,...
#
#                                                      q2
# rank
# 1     Would a different commodity spec (e.g., PDBC v...
# 2     Would a different commodity spec (e.g., PDBC v...
# 3     Would a different commodity spec (e.g., PDBC v...
# 4     Would a different commodity spec (e.g., PDBC v...

# %%
if checkpoint_runner:
    checkpoint_runner.run_checkpoint('checkpoint-candidate-review', {'candidates': final_ranked})

# %% [markdown]
# #### Index Substitution Analysis
#
# Explore whether an index that is a composite of sub-indexes can be used to simplify and reduce the number of indexes

# %%
from rbsa.substitution import analyze_substitutions, apply_recommended_substitutions

substitution_rules = cfg.get("substitutions", [])

if len(substitution_rules) > 0:
    print(f"Running substitution analysis with {len(substitution_rules)} rule(s)...\n")
    # Use X_full which includes substitution-only assets
    sub_results = analyze_substitutions(final_ranked, data["X_full"], data["y"], substitution_rules, verbose=True)
    
    # Apply recommended substitutions and re-rank
    final_candidates = apply_recommended_substitutions(final_ranked, sub_results, data["X_full"], data["y"], cfg, verbose=True)
    
    # Display final re-ranked results
    print(f"\n{'='*80}")
    print("FINAL RESULTS AFTER SUBSTITUTIONS")
    print(f"{'='*80}\n")
    print(format_final_results(final_candidates))
else:
    print("No substitution rules defined in config.yaml")
    final_candidates = final_ranked
# Out:
# Running substitution analysis with 3 rule(s)...
#
#
# ================================================================================
# Candidate 1: HYG, IWF, IWD, BIL, TIP
# ================================================================================
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to IWB
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.287, IWD=0.236
#     Swapped weights:  IWF=0.236, IWD=0.287
#     R² difference: -0.001872
#     RMSE difference: +0.000198
#     Materially different: True
#
#   Substitution Test (IWF + IWD → IWB):
#     Combined weight: 0.522
#     Original:    R²=0.979321, Adj-R²=0.978840, RMSE=0.004482
#     Substituted: R²=0.979159, Adj-R²=0.978773, RMSE=0.004499
#     Differences: ΔR²=-0.000162, ΔAdj-R²=-0.000067, ΔRMSE=+0.000018
#     Assets saved: 1
#     ✓ RECOMMEND SUBSTITUTION
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to SPY
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.287, IWD=0.236
#     Swapped weights:  IWF=0.236, IWD=0.287
#     R² difference: -0.001872
#     RMSE difference: +0.000198
#     Materially different: True
#
#   Substitution Test (IWF + IWD → SPY):
#     Combined weight: 0.522
#     Original:    R²=0.979321, Adj-R²=0.978840, RMSE=0.004482
#     Substituted: R²=0.977918, Adj-R²=0.977509, RMSE=0.004631
#     Differences: ΔR²=-0.001403, ΔAdj-R²=-0.001331, ΔRMSE=+0.000150
#     Assets saved: 1
#     ✗ Keep original components
#
#   IWM not found in model (needed for top-down expansion)
#
# ================================================================================
# Candidate 2: HYG, IWF, IWD, BIL, TIP
# ================================================================================
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to IWB
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.287, IWD=0.236
#     Swapped weights:  IWF=0.236, IWD=0.287
#     R² difference: -0.001872
#     RMSE difference: +0.000198
#     Materially different: True
#
#   Substitution Test (IWF + IWD → IWB):
#     Combined weight: 0.522
#     Original:    R²=0.979321, Adj-R²=0.978840, RMSE=0.004482
#     Substituted: R²=0.979159, Adj-R²=0.978773, RMSE=0.004499
#     Differences: ΔR²=-0.000162, ΔAdj-R²=-0.000067, ΔRMSE=+0.000018
#     Assets saved: 1
#     ✓ RECOMMEND SUBSTITUTION
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to SPY
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.287, IWD=0.236
#     Swapped weights:  IWF=0.236, IWD=0.287
#     R² difference: -0.001872
#     RMSE difference: +0.000198
#     Materially different: True
#
#   Substitution Test (IWF + IWD → SPY):
#     Combined weight: 0.522
#     Original:    R²=0.979321, Adj-R²=0.978840, RMSE=0.004482
#     Substituted: R²=0.977918, Adj-R²=0.977509, RMSE=0.004631
#     Differences: ΔR²=-0.001403, ΔAdj-R²=-0.001331, ΔRMSE=+0.000150
#     Assets saved: 1
#     ✗ Keep original components
#
#   IWM not found in model (needed for top-down expansion)
#
# ================================================================================
# Candidate 3: BIL, HYG, IWD, IWF
# ================================================================================
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to IWB
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.291, IWD=0.230
#     Swapped weights:  IWF=0.230, IWD=0.291
#     R² difference: -0.002642
#     RMSE difference: +0.000274
#     Materially different: True
#
#   Substitution Test (IWF + IWD → IWB):
#     Combined weight: 0.521
#     Original:    R²=0.978787, Adj-R²=0.978394, RMSE=0.004539
#     Substituted: R²=0.978267, Adj-R²=0.977966, RMSE=0.004595
#     Differences: ΔR²=-0.000521, ΔAdj-R²=-0.000428, ΔRMSE=+0.000055
#     Assets saved: 1
#     ✓ RECOMMEND SUBSTITUTION
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to SPY
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.291, IWD=0.230
#     Swapped weights:  IWF=0.230, IWD=0.291
#     R² difference: -0.002642
#     RMSE difference: +0.000274
#     Materially different: True
#
#   Substitution Test (IWF + IWD → SPY):
#     Combined weight: 0.521
#     Original:    R²=0.978787, Adj-R²=0.978394, RMSE=0.004539
#     Substituted: R²=0.977148, Adj-R²=0.976832, RMSE=0.004711
#     Differences: ΔR²=-0.001639, ΔAdj-R²=-0.001562, ΔRMSE=+0.000172
#     Assets saved: 1
#     ✗ Keep original components
#
#   IWM not found in model (needed for top-down expansion)
#
# ================================================================================
# Candidate 4: DBC, HYG, IEF, IWD, IWF, LQD, TIP
# ================================================================================
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to IWB
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.275, IWD=0.240
#     Swapped weights:  IWF=0.240, IWD=0.275
#     R² difference: -0.000881
#     RMSE difference: +0.000085
#     Materially different: False
#
#   Substitution Test (IWF + IWD → IWB):
#     Combined weight: 0.515
#     Original:    R²=0.974304, Adj-R²=0.973459, RMSE=0.004996
#     Substituted: R²=0.974927, Adj-R²=0.974224, RMSE=0.004935
#     Differences: ΔR²=+0.000623, ΔAdj-R²=+0.000764, ΔRMSE=-0.000061
#     Assets saved: 1
#     ✓ RECOMMEND SUBSTITUTION
#
# ✓ Found IWF + IWD → Testing bottom-up consolidation to SPY
#
#   Weight Swap Test (IWF ↔ IWD):
#     Original weights: IWF=0.275, IWD=0.240
#     Swapped weights:  IWF=0.240, IWD=0.275
#     R² difference: -0.000881
#     RMSE difference: +0.000085
#     Materially different: False
#
#   Substitution Test (IWF + IWD → SPY):
#     Combined weight: 0.515
#     Original:    R²=0.974304, Adj-R²=0.973459, RMSE=0.004996
#     Substituted: R²=0.974701, Adj-R²=0.973992, RMSE=0.004957
#     Differences: ΔR²=+0.000398, ΔAdj-R²=+0.000533, ΔRMSE=-0.000039
#     Assets saved: 1
#     ✓ RECOMMEND SUBSTITUTION
#
#   IWM not found in model (needed for top-down expansion)
#
# ================================================================================
# ✓ 5 substitutions recommended
# ================================================================================
#
# ================================================================================
# APPLYING RECOMMENDED SUBSTITUTIONS
# ================================================================================
#
# ✓ Applying: IWD + IWF → IWB
#   Original R²=0.979321, New R²=0.979159
#
#   Updated diagnostics:
#     R²=0.979159
#     RMSE=0.004499
#     Assets: HYG, BIL, TIP, IWB
#
# ✓ Applying: IWD + IWF → IWB
#   Original R²=0.979321, New R²=0.979159
#
#   Updated diagnostics:
#     R²=0.979159
#     RMSE=0.004499
#     Assets: HYG, BIL, TIP, IWB
#
# ✓ Applying: IWD + IWF → IWB
#   Original R²=0.978787, New R²=0.978267
#
#   Updated diagnostics:
#     R²=0.978267
#     RMSE=0.004595
#     Assets: BIL, HYG, IWB
#
# ✓ Multiple substitutes tested for IWD + IWF:
#   - IWB: Adj-R²=0.974224
#   - SPY: Adj-R²=0.973992
#   → Choosing BEST: IWB (Adj-R²=0.974224)
#   Original R²=0.974304, New R²=0.974927
#
#   Updated diagnostics:
#     R²=0.974927
#     RMSE=0.004935
#     Assets: DBC, HYG, IEF, LQD, TIP, IWB
#
# ================================================================================
# RE-RANKING AFTER SUBSTITUTIONS
# ================================================================================
#
# New Rankings (in_sample mode):
#   1. R²=0.979159, RMSE=0.004499 - HYG, BIL, TIP, IWB (1 substitution)
#   2. R²=0.979159, RMSE=0.004499 - HYG, BIL, TIP, IWB (1 substitution)
#   3. R²=0.978267, RMSE=0.004595 - BIL, HYG, IWB (1 substitution)
#   4. R²=0.974927, RMSE=0.004935 - DBC, HYG, IEF, LQD, TIP, IWB (1 substitution)
#
# ================================================================================
# FINAL CANDIDATES AFTER SUBSTITUTIONS
# ================================================================================
#
# Candidate 1 (Method A, after substitution):
#   Statistics: n_assets=4, R²=0.979159, Adj-R²=0.978773, RMSE=0.004499, MAE=0.002974, AIC=-1753.32, AICc=-1753.14, BIC=-1739.73
#   Assets:     IWB(0.522), HYG(0.292), BIL(0.136), TIP(0.050)
#
# Candidate 2 (Method D, after substitution):
#   Statistics: n_assets=4, R²=0.979159, Adj-R²=0.978773, RMSE=0.004499, MAE=0.002974, AIC=-1753.32, AICc=-1753.14, BIC=-1739.73
#   Assets:     IWB(0.522), HYG(0.292), BIL(0.136), TIP(0.050)
#
# Candidate 3 (Method C, after substitution):
#   Statistics: n_assets=3, R²=0.978267, Adj-R²=0.977966, RMSE=0.004595, MAE=0.003008, AIC=-1746.05, AICc=-1745.94, BIC=-1735.86
#   Assets:     IWB(0.521), HYG(0.307), BIL(0.172)
#
# Candidate 4 (Method B, after substitution):
#   Statistics: n_assets=6, R²=0.974927, Adj-R²=0.974224, RMSE=0.004935, MAE=0.003430, AIC=-1708.46, AICc=-1708.07, BIC=-1688.07
#   Assets:     IWB(0.515), HYG(0.302), TIP(0.165), LQD(0.014), DBC(0.004), IEF(0.000)
#
#
# ================================================================================
# FINAL RESULTS AFTER SUBSTITUTIONS
# ================================================================================
#
# Candidate 1 (Method A):
#   Statistics: n_assets=4, R²=0.979159, Adj-R²=0.978773, RMSE=0.004499, MAE=0.002974, AIC=-1753.32, AICc=-1753.14, BIC=-1739.73
#   Assets:     IWB(0.522), HYG(0.292), BIL(0.136), TIP(0.050)
#
# Candidate 2 (Method D):
#   Statistics: n_assets=4, R²=0.979159, Adj-R²=0.978773, RMSE=0.004499, MAE=0.002974, AIC=-1753.32, AICc=-1753.14, BIC=-1739.73
#   Assets:     IWB(0.522), HYG(0.292), BIL(0.136), TIP(0.050)
#
# Candidate 3 (Method C):
#   Statistics: n_assets=3, R²=0.978267, Adj-R²=0.977966, RMSE=0.004595, MAE=0.003008, AIC=-1746.05, AICc=-1745.94, BIC=-1735.86
#   Assets:     IWB(0.521), HYG(0.307), BIL(0.172)
#
# Candidate 4 (Method B):
#   Statistics: n_assets=6, R²=0.974927, Adj-R²=0.974224, RMSE=0.004935, MAE=0.003430, AIC=-1708.46, AICc=-1708.07, BIC=-1688.07
#   Assets:     IWB(0.515), HYG(0.302), TIP(0.165), LQD(0.014), DBC(0.004), IEF(0.000)

# %%
if checkpoint_runner:
    checkpoint_runner.run_checkpoint('checkpoint-final-selection', {'candidates': final_candidates[:3]})

# %% [markdown]
# #### AI-Powered Comprehensive Summary
#
# Synthesize and summarize results with actionable insights.

# %%
from rbsa.final_summary import create_summary_report

# Generate comprehensive AI summary of final results
print("\nGenerating AI-powered analysis...\n")

summary_report = create_summary_report(
    candidates=final_candidates,
    summarizer=summarizer,
    cfg=cfg,
    desmooth_diagnostics=data.get("desmooth_diagnostics")
)

print(summary_report["full"])
# Out:
# Generating AI-powered analysis...
#
# ANALYSIS CONFIGURATION:
#   Mode: in_sample
#   Number of candidates: 4
#   De-smoothing: Not needed
#
# ================================================================================
# AI ANALYSIS
# ================================================================================
#
# Here’s what the RBSA says about the portfolio, distilled to what matters:
#
# 1) Factor exposure and economic interpretation
# - Core risk drivers:
#   - US large-cap equity (IWB) ~52%: dominant driver; style appears core/blend, not distinctly growth or value.
#   - High yield credit (HYG) ~29–31%: sizable credit-spread beta; equity-like behavior in selloffs.
# - Defensive/liquidity:
#   - Cash/T-bills (BIL) ~14–17%: volatility dampener; return drag in risk-on markets.
# - Rates/inflation:
#   - TIP 0–5% in top fits (up to 16.5% in a less parsimonious candidate): modest to low inflation hedging; low interest rate duration overall.
# - Implied risk posture:
#   - Effective equity beta ≈ 0.7 (52% equity + equity-like component from HY). Expect material drawdowns in equity/credit stress, with limited duration ballast.
#
# 2) Model quality and parsimony
# - Fit is strong: R² ~0.979 (RMSE ~0.45%/month). Candidate 1/2 provide the best AIC/BIC.
# - Parsimony: Candidate 3 (3-factor: IWB/HYG/BIL) drops R² by only ~0.001 and improves simplicity with very similar economics. Candidate 4 adds tiny weights and worsens information criteria—likely overfitting.
# - Style resolution: Substitutions IWD/IWF → IWB indicate no stable growth/value tilt; broad market exposure dominates.
#
# 3) Notable differences between top candidates
# - Candidates 1/2 vs 3: The only real difference is a small TIP sleeve (~5%) in 1/2, replaced mainly by BIL in 3. Economic exposures are nearly identical.
# - Candidate 4: Introduces more TIP (16.5%) plus small LQD/DBC, but with weaker fit and unnecessary complexity.
#
# 4) Concerns and actionable recommendations
# - Concentration in risk-on betas: ~80% of risk budget sits in IWB + HYG. Expect underperformance when equities sell off and credit spreads widen. Consider:
#   - If downside resilience is desired: trim HYG, add rate ballast (IEF/TLT) or more TIP; optionally shift some HYG to IG credit (LQD) or short-duration HY.
#   - If carry/return is prioritized and drawdowns are acceptable: reduce BIL and add to IWB/HYG (acknowledging higher drawdown risk).
# - Style neutrality: No persistent growth/value tilt. If a tilt is intentional, replace part of IWB with IWF (growth) or IWD (value) and re-test stability.
# - Inflation profile: Current inflation sensitivity is modest. If inflation hedging is a goal, increase TIP to 10–15% and reduce BIL/HYG accordingly.
# - Monitoring and validation:
#   - Use Candidate 3 for ongoing reporting (similar fit, simpler).
#   - Run rolling/out-of-sample RBSA to check stability across regimes, especially around credit stress and rate shocks.
#
# Bottom line: The portfolio behaves like a ~50% US large-cap equity + ~30% high yield credit barbell with a cash cushion and minimal duration. Great in risk-on regimes, vulnerable to equity/credit drawdowns, with limited rate hedging unless TIP/duration is added.

# %%
if checkpoint_runner and checkpoint_runner.history:
    import json
    from datetime import datetime
    json.dump(checkpoint_runner.history, open(f'checkpoint_history_{datetime.now().strftime("%Y%m%d_%H%M%S")}.json', 'w'), indent=2, default=str)
